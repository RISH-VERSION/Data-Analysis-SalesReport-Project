# %%
import pandas as pd
import sqlalchemy as db
import mysql.connector

# %%
engine = db.create_engine(
    "mysql+mysqlconnector://root:white007@localhost:3306/superstore_db"
)

# %%
df = pd.read_csv('../data/Cleaned-Superstore.csv')

df.to_sql(
    name="superstore",     # Name of the target SQL table
    con=engine,            # SQLAlchemy engine connection
    if_exists="replace",    # How to behave if the table already exists
    index=False            # Do not write the DataFrame index as a column
)
# Out:
# 9994
